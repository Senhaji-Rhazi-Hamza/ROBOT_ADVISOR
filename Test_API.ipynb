# %%
# importing the requests library
import requests
import json

# %%
s = requests.Session()
s.auth = ('epita_user_5', 'dolphin23235')
s.headers.update({'x-test': 'true'})
URL = 'https://dolphin.jump-technology.com:3389/api/v1/asset/3'
# both 'x-test' and 'x-test2' are sent
r = s.get(URL ,verify = False)
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:794: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)

# %%
json.loads(r.text)
# Out:
# {'ASSET PRICE MODE': {'type': 'string', 'value': 'Par Défaut (configuration)'},
#  'ASSET_DATABASE_ID': {'type': 'int32', 'value': '3'},
#  'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#  'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#  'BLOOMBERG_CODE': {'type': 'string', 'value': 'ORLY UW Equity'},
#  'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BGZ8C2'},
#  'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#  'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#  'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#  'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2655'},
#  'FINAL_UNDERLYING': {'type': 'asset', 'value': '3'},
#  'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#  'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-03'},
#  'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#  'INDEXED_RATE': {'type': 'double', 'value': '0'},
#  'ISIN_CODE': {'type': 'string', 'value': 'US67103H1077'},
#  'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#  'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#  'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#  'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#  'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#  'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#  'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#  'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#  'LABEL': {'type': 'string', 'value': "O'REILLY AUTOMOT"},
#  'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '186,91 USD'},
#  'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '186,91 USD'},
#  'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '186,91 USD'},
#  'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#   'value': '2017-07-20T17:12:23.000Z'},
#  'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#  'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#  'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#   'value': 'PerVolLiquidityAlgorithm'},
#  'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#  'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNGS)'},
#  'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#  'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#  'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#  'MARKET_PLACE_DESC': {'type': 'string',
#   'value': 'NASDAQ/NGS (GLOBAL SELECT MARKET)'},
#  'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNGS'},
#  'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#  'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#  'MODIFICATION_DATE': {'type': 'date-time',
#   'value': '2017-07-20T17:12:23.000Z'},
#  'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#  'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#  'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#  'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#  'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#  'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#  'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#  'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#   'value': 'STOCK'},
#  'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#  'quote_value_type': {'type': 'string', 'value': 'Défaut'}}

# %%
# Out:
# True

# %%
import requests
import json
class RequestManadger:
    def __init__(self, url,  user = '', password = '',auth = True):
        self.url = url
        self.session = requests.Session()
        if (auth):
            if ((user != '') and (password != '')):
                self.user = user
                self.session.auth = (user, password)
                self.session.headers.update({'x-test': 'true'})
                r = s.get(self.url, verify = False)
               
            else :
                print("you should precise explicitly auth = false if "
                      "you dont want add a user name and a password")
        else:
            return self.session.get(self.url, verify = False)
    def get_request(self,req):
        r = self.session.get(self.url + "/" + req, verify = False) 
        return json.loads(r.text)

# %%
URL = 'https://dolphin.jump-technology.com:3389/api/v1'
user = 'epita_user_5'
pwd = 'dolphin23235'
rm = RequestManadger(URL,user, pwd)
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:794: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)

# %%
rm.get_request("asset")
# Out:
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py:794: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# [{'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '315'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'ABT UN EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000B9ZZG4'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5677'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '315'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'US0028241000'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ABBOTT LABS'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '49,43 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '49,43 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '49,43 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:35.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNYS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NEW YORK STOCK EXCHANGE, INC.'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNYS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '65'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:35.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '405'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'PLEUCOC FP Equity'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000C37W47'},
#   'BOND_RISK_COMPUTATION_MODE': {'type': 'string', 'value': 'Par défaut'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'no_place'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2641'},
#   'ELIGIBLE_PEA_PME': {'type': 'boolean', 'value': 'true'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '405'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'FUND'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-02'},
#   'FUND_TYPE': {'type': 'string', 'value': 'FCP'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'FR0010281477'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ABN-EUR CONV-C'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '193,81 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '193,81 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '193,81 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:32.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'No Place'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string', 'value': 'No Place'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Sans place de marché'},
#   'MIN_BUY_QTY': {'type': 'double', 'value': '1'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:32.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'OPCVM'},
#   'TRANSPARENCY_LIST': {'type': 'string', 'value': ''},
#   'TYPE': {'type': 'asset_type', 'value': 'FUND'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'FUND'},
#   'asset_custom_classification_action': {'type': 'string',
#    'value': 'non action'},
#   'asset_fund_info_administrator': {'type': 'string',
#    'value': 'CACEIS Fund Administration SA'},
#   'asset_fund_info_amf_date': {'type': 'date', 'value': '1997-11-06'},
#   'asset_fund_info_asset_class_focus': {'type': 'string',
#    'value': 'Fixed Income'},
#   'asset_fund_info_authorized_for_retail_investors': {'type': 'boolean',
#    'value': 'false'},
#   'asset_fund_info_bloomberg_ticker': {'type': 'string',
#    'value': 'PLEUCOC FP Equity'},
#   'asset_fund_info_comanager': {'type': 'string', 'value': 'SARRA REKIK'},
#   'asset_fund_info_company': {'type': 'string',
#    'value': 'ABN AMRO Investment Solutions'},
#   'asset_fund_info_creation_date': {'type': 'date', 'value': '1997-11-19'},
#   'asset_fund_info_depositary': {'type': 'string',
#    'value': 'CACEIS Bank France SA'},
#   'asset_fund_info_fund_leverage': {'type': 'boolean', 'value': 'false'},
#   'asset_fund_info_fund_open_pymt_shr': {'type': 'string',
#    'value': 'Accumulation'},
#   'asset_fund_info_fund_type': {'type': 'string', 'value': 'FCP'},
#   'asset_fund_info_geographical_focus': {'type': 'string', 'value': 'Europe'},
#   'asset_fund_info_is_euro_ucits': {'type': 'boolean', 'value': 'true'},
#   'asset_fund_info_is_feeded': {'type': 'boolean', 'value': 'false'},
#   'asset_fund_info_isin_code': {'type': 'string', 'value': 'FR0010281477'},
#   'asset_fund_info_manager_stated_fee': {'type': 'double', 'value': '1,35'},
#   'asset_fund_info_manager_stated_perf_fee': {'type': 'double', 'value': '20'},
#   'asset_fund_info_maximum_back_end_fee': {'type': 'double', 'value': '0'},
#   'asset_fund_info_maximum_front_end_fee': {'type': 'double', 'value': '2,5'},
#   'asset_fund_info_minimum_investment_shares': {'type': 'double',
#    'value': '1'},
#   'asset_fund_info_objective_long': {'type': 'string', 'value': 'Convertible'},
#   'asset_fund_info_strategy': {'type': 'string', 'value': 'Convertible'},
#   'asset_fund_info_valorisation_frequency': {'type': 'string',
#    'value': 'Journalière'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '61'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AC FP EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BB4980'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'PARIS'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5738'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '61'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'FR0000120404'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ACCOR SA'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '42 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '42 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '42 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:38.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'PARIS (XPAR)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'PARIS'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT PARIS'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XPAR'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '25'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:37.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '67'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Allemagne'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'ADS GY EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000FR1RP5'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'FRANKFURT'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5495'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '67'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-11-17'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'DE000A1EWWW0'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ADIDAS AG'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '179,1 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '179,1 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '179,1 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:38.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'FRANCFORT (XETR)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'FRANCFORT'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Allemagne'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string', 'value': 'XETRA'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XETR'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'Allemagne'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '44'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:37.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '16'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'ADBE UW EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BB5BP5'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5659'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '16'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'US00724F1012'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ADOBE SYS INC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '148,92 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '148,92 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '148,92 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:38.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNGS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NASDAQ/NGS (GLOBAL SELECT MARKET)'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNGS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:37.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '144'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'ADP FP EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000H292Q4'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'PARIS'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2841'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '144'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2006-06-15'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'FR0010340141'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'ADP'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '143,65 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '143,65 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '143,65 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'PARIS (XPAR)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'PARIS'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT PARIS'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XPAR'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '25'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '70'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AET UN EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000FJLJ51'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '4174'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '70'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2000-12-13'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'US00817Y1082'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AETNA INC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '154,24 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '154,24 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '154,24 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNYS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NEW YORK STOCK EXCHANGE, INC.'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNYS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '65'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '234'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AFL UN EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BBBRC7'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5677'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '234'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'US0010551028'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AFLAC INC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '77,89 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '77,89 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '77,89 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNYS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NEW YORK STOCK EXCHANGE, INC.'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNYS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '65'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:40.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '376'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AGFREEL FP Equity'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BMJ2B1'},
#   'BOND_RISK_COMPUTATION_MODE': {'type': 'string', 'value': 'Par défaut'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'no_place'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2633'},
#   'ELIGIBLE_PEA_PME': {'type': 'boolean', 'value': 'true'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '376'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'FUND'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-02'},
#   'FUND_TOTAL_SHARE': {'type': 'double', 'value': '99510'},
#   'FUND_TYPE': {'type': 'string', 'value': 'Fonds de fonds'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'FR0000992349'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AGIF-ALZ MU RE R'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '2212,77 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '2212,77 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '2212,77 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:33.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'No Place'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string', 'value': 'No Place'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Sans place de marché'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:33.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'OPCVM'},
#   'TRANSPARENCY_LIST': {'type': 'string', 'value': ''},
#   'TYPE': {'type': 'asset_type', 'value': 'FUND'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'FUND'},
#   'asset_custom_classification_action': {'type': 'string',
#    'value': 'non action'},
#   'asset_fund_info_administrator': {'type': 'string',
#    'value': 'Societe Generale Securities Services Net Asset Value SA'},
#   'asset_fund_info_amf_date': {'type': 'date', 'value': '2003-02-12'},
#   'asset_fund_info_asset_class_focus': {'type': 'string',
#    'value': 'Mixed Allocation'},
#   'asset_fund_info_authorized_for_retail_investors': {'type': 'boolean',
#    'value': 'false'},
#   'asset_fund_info_bloomberg_ticker': {'type': 'string',
#    'value': 'AGFREEL FP Equity'},
#   'asset_fund_info_company': {'type': 'string',
#    'value': 'Allianz Global Investors GmbH'},
#   'asset_fund_info_creation_date': {'type': 'date', 'value': '2003-03-03'},
#   'asset_fund_info_depositary': {'type': 'string',
#    'value': 'Societe Generale SA'},
#   'asset_fund_info_fund_leverage': {'type': 'boolean', 'value': 'false'},
#   'asset_fund_info_fund_open_pymt_shr': {'type': 'string',
#    'value': 'Accumulation'},
#   'asset_fund_info_fund_type': {'type': 'string', 'value': 'Fonds de fonds'},
#   'asset_fund_info_geographical_focus': {'type': 'string', 'value': 'Global'},
#   'asset_fund_info_is_euro_ucits': {'type': 'boolean', 'value': 'true'},
#   'asset_fund_info_is_feeded': {'type': 'boolean', 'value': 'false'},
#   'asset_fund_info_isin_code': {'type': 'string', 'value': 'FR0000992349'},
#   'asset_fund_info_manager_stated_fee': {'type': 'double', 'value': '1,4'},
#   'asset_fund_info_manager_stated_perf_fee': {'type': 'double', 'value': '0'},
#   'asset_fund_info_maximum_back_end_fee': {'type': 'double', 'value': '0'},
#   'asset_fund_info_maximum_front_end_fee': {'type': 'double', 'value': '3'},
#   'asset_fund_info_objective_long': {'type': 'string',
#    'value': 'Dynamic Allocation'},
#   'asset_fund_info_strategy': {'type': 'string',
#    'value': 'Dynamic Allocation'},
#   'asset_fund_info_total_number_of_shares': {'type': 'double',
#    'value': '99510'},
#   'asset_fund_info_valorisation_frequency': {'type': 'string',
#    'value': 'Journalière'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '109'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AD NA EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BBBC58'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'AMSTERDAM'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5753'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '109'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-02'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'NL0011794037'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AHOL DELHAIZE NV'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '17,285 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '17,285 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '17,285 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:42.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'AMSTERDAM (XAMS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'AMSTERDAM'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT AMSTERDAM'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XAMS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '38'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:42.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '31'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AIR FP EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000CSHLR0'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'PARIS'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '4357'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '31'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2000-07-10'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'NL0000235190'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AIRBUS GROUP SE'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '73,69 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '73,69 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '73,69 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:43.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'PARIS (XPAR)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'PARIS'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT PARIS'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XPAR'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '25'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:42.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '68'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AI FP EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BLGLW1'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'PARIS'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5738'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '68'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'FR0000120073'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AIR LIQUIDE SA'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '109,25 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '109,25 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '109,25 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:43.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'PARIS (XPAR)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'PARIS'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT PARIS'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XPAR'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'France'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '25'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:09:42.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_PLACE': {'type': 'string', 'value': 'Mercato Continuo Italiano'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TELEKURS_QUOTE_PLACE_CODE': {'type': 'int32', 'value': '46'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '169'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'AKZA NA EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BW45W5'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'AMSTERDAM'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '5753'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '169'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '1995-01-02'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'NL0000009132'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'AKZO NOBEL'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '78,15 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '78,15 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '78,15 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
# ...
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '198,34 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '198,34 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '198,34 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:28.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNYS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NEW YORK STOCK EXCHANGE, INC.'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNYS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '65'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:28.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '98'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'WKL NA EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BCHRW7'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'AMSTERDAM'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2701'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '98'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-02'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'NL0000395903'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'true'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'true'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'WOLTERS KLUWER'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '37,295 EUR'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value',
#    'value': '37,295 EUR'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '37,295 EUR'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:28.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'AMSTERDAM (XAMS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'AMSTERDAM'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'EUR'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NYSE EURONEXT - EURONEXT AMSTERDAM'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XAMS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'Pays-Bas'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '38'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:28.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '172'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Royaume-Uni'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'WPP LN EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000BF6B57'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'LONDON'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'GBp'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2666'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '172'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-02'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'JE00B8KF9B49'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'WPP PLC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '1560 GBp'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '1560 GBp'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '1560 GBp'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:29.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'LONDRES (XLON)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'LONDRES'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'Royaume-Uni'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'GBP'},
#   'MARKET_PLACE_DESC': {'type': 'string', 'value': 'LONDON STOCK EXCHANGE'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XLON'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'Royaume-Uni'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '36'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:29.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '76'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'XLNX UW Equity'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000C0FFN0'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2655'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '76'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'US9839191015'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'XILINX INC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '65,59 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '65,59 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '65,59 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:30.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNGS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NASDAQ/NGS (GLOBAL SELECT MARKET)'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNGS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:30.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}},
#  {'ASSET PRICE MODE': {'type': 'string',
#    'value': 'Par Défaut (configuration)'},
#   'ASSET_DATABASE_ID': {'type': 'int32', 'value': '149'},
#   'ASSET_OR_MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'ASSET_STATUS': {'type': 'asset_status', 'value': 'normal'},
#   'BLOOMBERG_CODE': {'type': 'string', 'value': 'XL UN EQUITY'},
#   'BLOOMBERG_ID': {'type': 'string', 'value': 'BBG000C9W518'},
#   'CITY_OR_ACRONYM_OR_NAME': {'type': 'string', 'value': 'NEW YORK'},
#   'CREATION_DATE': {'type': 'date', 'value': '2017-07-13'},
#   'CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'DAILY_PRICE_COUNT': {'type': 'int32', 'value': '2655'},
#   'FINAL_UNDERLYING': {'type': 'asset', 'value': '149'},
#   'FINAL_UNDERLYING_TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'FIRST_QUOTE_DATE': {'type': 'date', 'value': '2007-01-03'},
#   'GLOBAL_TYPE': {'type': 'string', 'value': 'Actif'},
#   'INDEXED_RATE': {'type': 'double', 'value': '0'},
#   'ISIN_CODE': {'type': 'string', 'value': 'IE00B5LRLL25'},
#   'IS_COMPOSITE': {'type': 'boolean', 'value': 'false'},
#   'IS_DEPOSITARY_QUOTES': {'type': 'boolean', 'value': 'false'},
#   'IS_EUROLAND': {'type': 'boolean', 'value': 'false'},
#   'IS_EURONEXT': {'type': 'boolean', 'value': 'false'},
#   'IS_PORTFOLIO': {'type': 'boolean', 'value': 'false'},
#   'IS_PUBLICLY_TRADED': {'type': 'boolean', 'value': 'true'},
#   'IS_REAL_ESTATE_FUND': {'type': 'boolean', 'value': 'false'},
#   'IS_STRUCTURED_PRODUCT': {'type': 'boolean', 'value': 'false'},
#   'LABEL': {'type': 'string', 'value': 'XL GROUP PLC'},
#   'LAST_CLOSE_VALUE': {'type': 'currency_value', 'value': '46,08 USD'},
#   'LAST_CLOSE_VALUE_IN_CURR': {'type': 'currency_value', 'value': '46,08 USD'},
#   'LAST_GROSS_VALUE': {'type': 'currency_value', 'value': '46,08 USD'},
#   'LAST_QUOTES_UPDATE_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:30.000Z'},
#   'LAST_QUOTE_DATE': {'type': 'date', 'value': '2017-07-19'},
#   'LAST_QUOTE_SOURCE': {'type': 'string', 'value': 'Bloomberg'},
#   'LIQUIDITY_ALGO': {'type': 'liquidity_algorithm',
#    'value': 'PerVolLiquidityAlgorithm'},
#   'MARKET_CAP_CATEGORY': {'type': 'string', 'value': 'Non actif'},
#   'MARKET_PLACE': {'type': 'string', 'value': 'NEW YORK (XNYS)'},
#   'MARKET_PLACE_CITY': {'type': 'string', 'value': 'NEW YORK'},
#   'MARKET_PLACE_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_CURRENCY': {'type': 'asset_currency', 'value': 'USD'},
#   'MARKET_PLACE_DESC': {'type': 'string',
#    'value': 'NEW YORK STOCK EXCHANGE, INC.'},
#   'MARKET_PLACE_MIC': {'type': 'string', 'value': 'XNYS'},
#   'MARKET_PLACE_OR_ASSET_COUNTRY': {'type': 'string', 'value': 'USA'},
#   'MARKET_PLACE_TELEKURS': {'type': 'int32', 'value': '65'},
#   'MARKET_PLACE_TYPE': {'type': 'string', 'value': 'Marché réglementé'},
#   'MODIFICATION_DATE': {'type': 'date-time',
#    'value': '2017-07-20T17:13:30.000Z'},
#   'PAY_ACCOUNT_ON_DEFAULT': {'type': 'boolean', 'value': 'false'},
#   'PORT_ASSET_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_CONTENT_COUNT': {'type': 'int32', 'value': '0'},
#   'PORT_LINE_COUNT': {'type': 'int32', 'value': '0'},
#   'QUOTE_TYPE': {'type': 'asset_quote_type', 'value': 'value'},
#   'SUB_TYPE': {'type': 'asset_sub_type', 'value': 'ORDINARY_STOCK'},
#   'TYPE': {'type': 'asset_type', 'value': 'STOCK'},
#   'asset_custom_classification_Tab. de bord GSM': {'type': 'asset_type',
#    'value': 'STOCK'},
#   'asset_custom_classification_action': {'type': 'string', 'value': 'action'},
#   'quote_value_type': {'type': 'string', 'value': 'Défaut'}}]
